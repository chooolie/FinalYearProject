# %%
import pandas as pd
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from scipy.spatial.distance import cosine


def age_occupation(age,occupation):
    users = pd.read_csv("users.csv")
    ratings = pd.read_csv("ratings.csv")
    movies = pd.read_csv("movies.csv")
    ratings2 = pd.merge(movies, ratings, on = 'movieId')
    information = pd.merge(ratings, users, on='userId')
    user_demo = information.loc[(information.Occupation == occupation)&(information.rating >= 2.5)&(information.Age == age)]
    movie_data = pd.merge(ratings, movies, on='movieId')
    ratings_mean_count = pd.DataFrame(movie_data.groupby('title')['rating'].mean())
    ratings_mean_count['rating_counts'] = pd.DataFrame(movie_data.groupby('title')['rating'].count())
    user_avg_rating = pd.DataFrame(user_demo.groupby('movieId')['rating'].mean())
    user_avg_rating['count_ratings'] = user_demo.groupby('movieId')['rating'].count()
    hundred_most_voted = user_avg_rating.sort_values('count_ratings', ascending=False).head(50)
    top_10 = hundred_most_voted.sort_values('rating', ascending=False).head(15)
    links = pd.read_csv("links.csv")
    sim = pd.merge(top_10, links, on='movieId')
    sim = pd.merge(sim, movies, on='movieId')
    sim = sim.values
    return sim

def gender_age(age,gender):
    users = pd.read_csv("users.csv")
    ratings = pd.read_csv("ratings.csv")
    movies = pd.read_csv("movies.csv")
    ratings2 = pd.merge(movies, ratings, on = 'movieId')
    information = pd.merge(ratings, users, on='userId')
    user_demo = information.loc[(information.Gender == gender)&(information.rating >= 2.5)&(information.Age == age)]
    movie_data = pd.merge(ratings, movies, on='movieId')
    ratings_mean_count = pd.DataFrame(movie_data.groupby('title')['rating'].mean())
    ratings_mean_count['rating_counts'] = pd.DataFrame(movie_data.groupby('title')['rating'].count())
    user_avg_rating = pd.DataFrame(user_demo.groupby('movieId')['rating'].mean())
    user_avg_rating['count_ratings'] = user_demo.groupby('movieId')['rating'].count()
    hundred_most_voted = user_avg_rating.sort_values('count_ratings', ascending=False).head(50)
    top_10 = hundred_most_voted.sort_values('rating', ascending=False).head(15)
    links = pd.read_csv("links.csv")
    sim = pd.merge(top_10, links, on='movieId')
    sim = pd.merge(sim, movies, on='movieId')
    sim = sim.values
    return sim



def gender_occupation(gender,occupation):
    users = pd.read_csv("users.csv")
    ratings = pd.read_csv("ratings.csv")
    movies = pd.read_csv("movies.csv")
    ratings2 = pd.merge(movies, ratings, on = 'movieId')
    information = pd.merge(ratings, users, on='userId')
    user_demo = information.loc[(information.Occupation == occupation)&(information.rating >= 3)&(information.Gender == gender)]
    movie_data = pd.merge(ratings, movies, on='movieId')
    ratings_mean_count = pd.DataFrame(movie_data.groupby('title')['rating'].mean())
    ratings_mean_count['rating_counts'] = pd.DataFrame(movie_data.groupby('title')['rating'].count())
    user_avg_rating = pd.DataFrame(user_demo.groupby('movieId')['rating'].mean())
    user_avg_rating['count_ratings'] = user_demo.groupby('movieId')['rating'].count()
    hundred_most_voted = user_avg_rating.sort_values('count_ratings', ascending=False).head(50)
    top_10 = hundred_most_voted.sort_values('rating', ascending=False).head(15)
    links = pd.read_csv("links.csv")
    sim = pd.merge(top_10, links, on='movieId')
    sim = pd.merge(sim, movies, on='movieId')
    sim = sim.values
    return sim

# %%
rec_movies = age_occupation('25-34','academic/educator')
movies = []
for mov in rec_movies:
    movies.append(int(mov[0]))

rec_movies2 = gender_age('25-34','F')
movies2= []
for mov in rec_movies2:
    movies2.append(int(mov[0]))

rec_movies3 = gender_occupation('F', 'academic/educator')
movies3= []
for mov in rec_movies3:
    movies3.append(int(mov[0]))
    
rec_movies
# Out:
# array([[110, 4.375, 4, 112573, 197.0, 'Braveheart (1995)',
#         'Action|Drama|War'],
#        [296, 4.3, 5, 110912, 680.0, 'Pulp Fiction (1994)',
#         'Comedy|Crime|Drama|Thriller'],
#        [2571, 4.3, 5, 133093, 603.0, 'Matrix, The (1999)',
#         'Action|Sci-Fi|Thriller'],
#        [318, 4.285714285714286, 7, 111161, 278.0,
#         'Shawshank Redemption, The (1994)', 'Crime|Drama'],
#        [356, 4.285714285714286, 7, 109830, 13.0, 'Forrest Gump (1994)',
#         'Comedy|Drama|Romance|War'],
#        [541, 4.25, 4, 83658, 78.0, 'Blade Runner (1982)',
#         'Action|Sci-Fi|Thriller'],
#        [33794, 4.25, 4, 372784, 272.0, 'Batman Begins (2005)',
#         'Action|Crime|IMAX'],
#        [4027, 4.25, 4, 190590, 134.0,
#         'O Brother, Where Art Thou? (2000)', 'Adventure|Comedy|Crime'],
#        [1210, 4.2, 5, 86190, 1892.0,
#         'Star Wars: Episode VI - Return of the Jedi (1983)',
#         'Action|Adventure|Sci-Fi'],
#        [2028, 4.2, 5, 120815, 857.0, 'Saving Private Ryan (1998)',
#         'Action|Drama|War'],
#        [2959, 4.2, 5, 137523, 550.0, 'Fight Club (1999)',
#         'Action|Crime|Drama|Thriller'],
#        [4306, 4.166666666666667, 3, 126029, 808.0, 'Shrek (2001)',
#         'Adventure|Animation|Children|Comedy|Fantasy|Romance'],
#        [260, 4.142857142857143, 7, 76759, 11.0,
#         'Star Wars: Episode IV - A New Hope (1977)',
#         'Action|Adventure|Sci-Fi'],
#        [1584, 4.125, 4, 118884, 686.0, 'Contact (1997)', 'Drama|Sci-Fi'],
#        [7438, 4.125, 4, 378194, 393.0, 'Kill Bill: Vol. 2 (2004)',
#         'Action|Drama|Thriller']], dtype=object)

# %%
from collections import Counter
most_frequent = []
most_frequent.extend(movies)
most_frequent.extend(movies2)
most_frequent.extend(movies3)
recommendations = [word for word, word_count in Counter(most_frequent).most_common(20)]

recommendations
mov = pd.read_csv("movies.csv")
b = pd.DataFrame(recommendations)
b.columns = ['movieId']

c= pd.merge(b, mov, on='movieId')
#c=b.merge(movies, on = 'movieId')
#type(movies)
c.to_csv('topdemo.csv')
